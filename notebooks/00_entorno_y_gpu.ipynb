# %% [markdown]
# # 00 — Entorno y GPU
#
# Verifica que el notebook se ejecuta en la estación `g5.2xlarge` y que PyTorch puede utilizar la NVIDIA A10G. No instala paquetes ni imprime secretos. El código y este notebook se versionan; pesos, datos privados y checkpoints no.

# %%
from pathlib import Path
import json
import sys

ROOT = Path.cwd()
if ROOT.name == "notebooks":
    ROOT = ROOT.parent
sys.path.insert(0, str(ROOT))
from scripts.aulatex_training.motor_training import environment_report

report = environment_report()
print(json.dumps(report, ensure_ascii=False, indent=2))
assert (ROOT / "scripts" / "aulatex").is_dir(), "Abra el notebook desde el repositorio AulaTeX"
print("GPU lista" if report["cuda_available"] else "CUDA no disponible: ejecute en la estación A10G")
